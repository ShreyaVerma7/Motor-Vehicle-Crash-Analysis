# %%
import pandas as pd
import numpy as np

# %%
df_og = pd.read_csv('Motor_Vehicle_Collisions_Crashes.csv', na_values = ["", "NA", " "])
# Out:
# /Users/arunitmaity/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_og.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df_og['BOROUGH'].unique()
# Out:
# array([nan, 'BROOKLYN', 'QUEENS', 'STATEN ISLAND', 'BRONX', 'MANHATTAN'],
#       dtype=object)

# %%
df_og['BOROUGH'].value_counts()
# Out:
# BROOKLYN         398022
# QUEENS           338695
# MANHATTAN        291333
# BRONX            183351
# STATEN ISLAND     53311
# Name: BOROUGH, dtype: int64

# %%
df_og
# Out:
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0        04/14/2021       5:32        NaN      NaN        NaN        NaN
# 1        04/13/2021      21:35   BROOKLYN  11217.0  40.683580 -73.976170
# 2        04/15/2021      16:15        NaN      NaN        NaN        NaN
# 3        04/13/2021      16:00   BROOKLYN  11222.0        NaN        NaN
# 4        04/12/2021       8:25        NaN      NaN   0.000000   0.000000
# ...             ...        ...        ...      ...        ...        ...
# 1829486  07/06/2012      15:09  MANHATTAN    10035  40.801235 -73.941815
# 1829487  07/03/2012      17:30     QUEENS    11102  40.774711 -73.933386
# 1829488  07/01/2012      15:30   BROOKLYN    11236  40.645032 -73.919978
# 1829489  07/08/2012      18:30        NaN      NaN  40.786122 -73.804078
# 1829490  07/05/2012      23:00     QUEENS    11367  40.719910 -73.809039
#
#                           LOCATION                    ON STREET NAME  \
# ...

# %%
df_temp = df_og[df_og['VEHICLE TYPE CODE 1'].isna()].reset_index(drop = True)
df_0 = df_temp[['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
       'LONGITUDE','VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
       'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']]
df_0 = df_0[df_0['BOROUGH'].notna()].reset_index(drop = True)
df_0
# Out:
#       CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0     04/15/2021      20:13      BRONX  10457.0  40.847440 -73.899680
# 1     04/16/2021      20:26  MANHATTAN  10032.0  40.836555 -73.943060
# 2     04/15/2021      19:39   BROOKLYN  11226.0  40.652927 -73.959335
# 3     04/14/2021      10:00   BROOKLYN  11207.0  40.657894 -73.881530
# 4     04/07/2021      13:25   BROOKLYN  11219.0  40.631573 -73.995470
# ...          ...        ...        ...      ...        ...        ...
# 7431  06/09/2013      20:30   BROOKLYN    11237  40.699166 -73.914914
# 7432  12/24/2012      19:40     QUEENS    11434  40.691029 -73.780782
# 7433  12/25/2012      17:20     QUEENS    11434  40.686686 -73.787662
# 7434  11/20/2012      12:00      BRONX    10457  40.837643 -73.903339
# 7435  07/12/2012      16:15  MANHATTAN    10003  40.735313 -73.994118
#
#      VEHICLE TYPE CODE 1 VEHICLE TYPE CODE 2 VEHICLE TYPE CODE 3  \
# ...

# %%
df_temp = df_og[df_og['VEHICLE TYPE CODE 1'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 2'].isna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 3'].isna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 4'].isna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 5'].isna()].reset_index(drop = True)
df_1 = df_temp[['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
       'LONGITUDE', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
       'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']]
df_1 = df_1[df_1['BOROUGH'].notna()].reset_index(drop = True)
df_1
# Out:
#         CRASH DATE CRASH TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0       04/13/2021      21:35       BROOKLYN  11217.0  40.683580 -73.976170
# 1       04/13/2021      16:00       BROOKLYN  11222.0        NaN        NaN
# 2       04/11/2021      21:06       BROOKLYN  11226.0        NaN        NaN
# 3       04/15/2021      20:00  STATEN ISLAND  10304.0        NaN        NaN
# 4       02/26/2021      14:50          BRONX  10461.0  40.843464 -73.836000
# ...            ...        ...            ...      ...        ...        ...
# 218939  07/05/2012      10:45      MANHATTAN    10025  40.795326 -73.971288
# 218940  07/08/2012      23:15       BROOKLYN    11205  40.689445 -73.955121
# 218941  07/06/2012      19:50       BROOKLYN    11230  40.627156 -73.965625
# 218942  07/03/2012      15:22       BROOKLYN    11212  40.661997 -73.919593
# 218943  07/08/2012      15:00         QUEENS    11102  40.767228 -73.918907
#
# ...

# %%
df_temp = df_og[df_og['VEHICLE TYPE CODE 1'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 2'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 3'].isna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 4'].isna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 5'].isna()].reset_index(drop = True)
df_2 = df_temp[['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
       'LONGITUDE', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
       'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']]
df_2 = df_2[df_2['BOROUGH'].notna()].reset_index(drop = True)
df_2
# Out:
#         CRASH DATE CRASH TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0       04/13/2021      17:30         QUEENS  11106.0        NaN        NaN
# 1       05/21/2019      22:50       BROOKLYN  11201.0  40.697540 -73.983120
# 2       03/31/2021      22:20       BROOKLYN  11234.0  40.626457 -73.918000
# 3       04/06/2021      22:58  STATEN ISLAND  10312.0  40.526894 -74.167280
# 4       04/15/2021      13:30          BRONX  10461.0  40.857365 -73.846570
# ...            ...        ...            ...      ...        ...        ...
# 965730  07/07/2012      17:35       BROOKLYN    11235  40.575802 -73.961137
# 965731  07/06/2012      15:09      MANHATTAN    10035  40.801235 -73.941815
# 965732  07/03/2012      17:30         QUEENS    11102  40.774711 -73.933386
# 965733  07/01/2012      15:30       BROOKLYN    11236  40.645032 -73.919978
# 965734  07/05/2012      23:00         QUEENS    11367  40.719910 -73.809039
#
#                         VEHICLE TYPE CODE 1  \
# ...

# %%
df_temp = df_og[df_og['VEHICLE TYPE CODE 1'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 2'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 3'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 4'].isna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 5'].isna()].reset_index(drop = True)
df_3 = df_temp[['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
       'LONGITUDE', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
       'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']]
df_3 = df_3[df_3['BOROUGH'].notna()].reset_index(drop = True)
df_3
# Out:
#        CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0      04/16/2021      23:20   BROOKLYN  11226.0  40.649788 -73.962200
# 1      04/10/2021      12:00      BRONX  10453.0  40.856014 -73.912130
# 2      04/16/2021      15:05   BROOKLYN  11237.0  40.708805 -73.925770
# 3      04/01/2021       0:10  MANHATTAN  10027.0  40.805138 -73.945244
# 4      04/15/2021      16:00   BROOKLYN  11207.0  40.667250 -73.887990
# ...           ...        ...        ...      ...        ...        ...
# 56060  07/03/2012      12:26      BRONX    10451  40.827245 -73.924047
# 56061  07/03/2012      15:30   BROOKLYN    11236  40.642245 -73.910764
# 56062  07/05/2012       9:25     QUEENS    11355  40.742296 -73.810133
# 56063  07/05/2012      12:50     QUEENS    11417  40.672151 -73.843181
# 56064  07/07/2012      10:40   BROOKLYN    11214  40.611068 -74.001304
#
#                        VEHICLE TYPE CODE 1  \
# 0      Station Wagon/Sport Utility Vehicle
# ...

# %%
df_temp = df_og[df_og['VEHICLE TYPE CODE 1'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 2'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 3'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 4'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 5'].isna()].reset_index(drop = True)
df_4 = df_temp[['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
       'LONGITUDE', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
       'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']]
df_4 = df_4[df_4['BOROUGH'].notna()].reset_index(drop = True)
df_4
# Out:
#        CRASH DATE CRASH TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0      04/14/2021      16:30  STATEN ISLAND  10308.0  40.542908 -74.155790
# 1      04/14/2021       3:39       BROOKLYN  11230.0  40.619396 -73.969574
# 2      04/16/2021      11:45       BROOKLYN  11222.0  40.727146 -73.954735
# 3      04/13/2021       8:24         QUEENS  11436.0  40.678750 -73.794000
# 4      04/14/2021      22:32       BROOKLYN  11208.0  40.673252 -73.877730
# ...           ...        ...            ...      ...        ...        ...
# 11901  07/04/2012       3:35      MANHATTAN    10035  40.802077 -73.934063
# 11902  07/07/2012      19:55         QUEENS    11417  40.673748 -73.843232
# 11903  07/09/2012       2:10      MANHATTAN    10040  40.863572 -73.926012
# 11904  07/10/2012      20:15          BRONX    10456  40.835012 -73.912059
# 11905  07/10/2012       8:00      MANHATTAN    10128  40.783937 -73.952342
#
#                        VEHICLE TYPE CODE 1  \
# ...

# %%
df_temp = df_og[df_og['VEHICLE TYPE CODE 1'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 2'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 3'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 4'].notna()]
df_temp = df_temp[df_temp['VEHICLE TYPE CODE 5'].notna()].reset_index(drop = True)
df_5 = df_temp[['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
       'LONGITUDE', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
       'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']]
df_5 = df_5[df_5['BOROUGH'].notna()].reset_index(drop = True)
df_5
# Out:
#       CRASH DATE CRASH TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0     04/16/2021       7:30       BROOKLYN  11226.0  40.638313 -73.957510
# 1     04/16/2021      16:28       BROOKLYN  11205.0  40.694836 -73.969150
# 2     04/17/2021      23:40       BROOKLYN  11226.0  40.648075 -73.959590
# 3     04/17/2021       3:00       BROOKLYN  11203.0  40.655754 -73.924030
# 4     04/18/2021       8:59          BRONX  10461.0  40.857014 -73.843070
# ...          ...        ...            ...      ...        ...        ...
# 4621  07/05/2012       7:00  STATEN ISLAND    10310  40.634300 -74.120240
# 4622  07/03/2012       5:30      MANHATTAN    10030  40.815206 -73.947490
# 4623  07/06/2012      18:46       BROOKLYN    11234  40.634483 -73.918852
# 4624  07/05/2012      18:35         QUEENS    11434  40.679653 -73.777229
# 4625  07/05/2012       3:06         QUEENS    11358  40.769451 -73.790185
#
#      VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# ...

# %%
df_0['BOROUGH'].value_counts()
df_0_map = pd.DataFrame(df_0['BOROUGH'].value_counts()).reset_index()
df_0_map.columns = ['Borough', 'Count']
df_0_map['boro_code'] = [3, 4, 1, 2, 5]
df_0_map
# Out:
#          Borough  Count  boro_code
# 0       BROOKLYN   2393          3
# 1         QUEENS   1682          4
# 2      MANHATTAN   1675          1
# 3          BRONX   1413          2
# 4  STATEN ISLAND    273          5

# %%
df_1['BOROUGH'].value_counts()
df_1_map = pd.DataFrame(df_1['BOROUGH'].value_counts()).reset_index()
df_1_map.columns = ['Borough', 'Count']
df_1_map['boro_code'] = [3, 4, 1, 2, 5]
df_1_map
# Out:
#          Borough  Count  boro_code
# 0       BROOKLYN  72205          3
# 1         QUEENS  57522          4
# 2      MANHATTAN  40389          1
# 3          BRONX  38674          2
# 4  STATEN ISLAND  10154          5

# %%
df_2['BOROUGH'].value_counts()
df_2_map = pd.DataFrame(df_2['BOROUGH'].value_counts()).reset_index()
df_2_map.columns = ['Borough', 'Count']
df_2_map['boro_code'] = [3, 4, 1, 2, 5]
df_2_map
# Out:
#          Borough   Count  boro_code
# 0       BROOKLYN  297202          3
# 1         QUEENS  256989          4
# 2      MANHATTAN  239821          1
# 3          BRONX  132491          2
# 4  STATEN ISLAND   39232          5

# %%
df_3['BOROUGH'].value_counts()
df_3_map = pd.DataFrame(df_3['BOROUGH'].value_counts()).reset_index()
df_3_map.columns = ['Borough', 'Count']
df_3_map['boro_code'] = [3, 4, 1, 2, 5]
df_3_map
# Out:
#          Borough  Count  boro_code
# 0       BROOKLYN  19692          3
# 1         QUEENS  17441          4
# 2          BRONX   8137          1
# 3      MANHATTAN   7808          2
# 4  STATEN ISLAND   2987          5

# %%
df_4['BOROUGH'].value_counts()
df_4_map = pd.DataFrame(df_4['BOROUGH'].value_counts()).reset_index()
df_4_map.columns = ['Borough', 'Count']
df_4_map['boro_code'] = [3, 4, 1, 2, 5]
df_4_map
# Out:
#          Borough  Count  boro_code
# 0       BROOKLYN   4600          3
# 1         QUEENS   3680          4
# 2          BRONX   1899          1
# 3      MANHATTAN   1193          2
# 4  STATEN ISLAND    534          5

# %%
df_5['BOROUGH'].value_counts()
df_5_map = pd.DataFrame(df_5['BOROUGH'].value_counts()).reset_index()
df_5_map.columns = ['Borough', 'Count']
df_5_map['boro_code'] = [3, 4, 1, 2, 5]
df_5_map
# Out:
#          Borough  Count  boro_code
# 0       BROOKLYN   1930          3
# 1         QUEENS   1381          4
# 2          BRONX    737          1
# 3      MANHATTAN    447          2
# 4  STATEN ISLAND    131          5

# %%
import geopandas as gpd

# %%
coords = gpd.read_file('js/Borough Boundaries.geojson')

# %%
coords = coords.drop('shape_leng', axis=1)

# %%
coords
# Out:
#   boro_code      boro_name     shape_area  \
# 0         1      Manhattan  636620785.656
# 1         2          Bronx  1187193544.78
# 2         3       Brooklyn  1934174207.47
# 3         5  Staten Island  1623631283.35
# 4         4         Queens  3040205596.49
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...
# 1  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...
# 2  MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...
# 3  MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...
# 4  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...

# %%
df_0_map.to_csv('js/0_map.csv')
df_1_map.to_csv('js/1_map.csv')
df_2_map.to_csv('js/2_map.csv')
df_3_map.to_csv('js/3_map.csv')
df_4_map.to_csv('js/4_map.csv')
df_5_map.to_csv('js/5_map.csv')
